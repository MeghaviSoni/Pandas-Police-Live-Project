# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Meghavi Soni\Downloads\police_project.csv")

# %%
data
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
data["county_name"].head(20)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# Name: county_name, dtype: float64

# %%
data["county_name"].tail(50)
# Out:
# 91691   NaN
# 91692   NaN
# 91693   NaN
# 91694   NaN
# 91695   NaN
# 91696   NaN
# 91697   NaN
# 91698   NaN
# 91699   NaN
# 91700   NaN
# 91701   NaN
# 91702   NaN
# 91703   NaN
# 91704   NaN
# 91705   NaN
# 91706   NaN
# 91707   NaN
# 91708   NaN
# 91709   NaN
# 91710   NaN
# 91711   NaN
# 91712   NaN
# 91713   NaN
# 91714   NaN
# 91715   NaN
# 91716   NaN
# 91717   NaN
# 91718   NaN
# 91719   NaN
# 91720   NaN
# 91721   NaN
# 91722   NaN
# 91723   NaN
# 91724   NaN
# 91725   NaN
# 91726   NaN
# 91727   NaN
# 91728   NaN
# 91729   NaN
# 91730   NaN
# 91731   NaN
# 91732   NaN
# 91733   NaN
# 91734   NaN
# 91735   NaN
# 91736   NaN
# 91737   NaN
# 91738   NaN
# 91739   NaN
# 91740   NaN
# Name: county_name, dtype: float64

# %%
data["county_name"].unique()
# Out:
# array([nan])

# %%
data["search_type"].unique()
# Out:
# array([nan, 'Incident to Arrest,Protective Frisk', 'Probable Cause',
#        'Incident to Arrest', 'Probable Cause,Reasonable Suspicion',
#        'Incident to Arrest,Inventory,Probable Cause',
#        'Incident to Arrest,Inventory',
#        'Incident to Arrest,Probable Cause', 'Protective Frisk',
#        'Reasonable Suspicion', 'Inventory', 'Inventory,Protective Frisk',
#        'Incident to Arrest,Reasonable Suspicion',
#        'Incident to Arrest,Probable Cause,Protective Frisk',
#        'Probable Cause,Protective Frisk',
#        'Incident to Arrest,Inventory,Protective Frisk',
#        'Protective Frisk,Reasonable Suspicion',
#        'Incident to Arrest,Inventory,Reasonable Suspicion',
#        'Inventory,Probable Cause',
#        'Incident to Arrest,Protective Frisk,Reasonable Suspicion',
#        'Inventory,Probable Cause,Protective Frisk',
#        'Inventory,Reasonable Suspicion',
#        'Incident to Arrest,Probable Cause,Reasonable Suspicion',
# ...

# %%
data.drop("county_name",axis=1,inplace=True)

# %%
data
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  datetime64[ns]
#  2   driver_gender       86406 non-null  object
#  3   driver_age_raw      86414 non-null  float64
#  4   driver_age          86120 non-null  float64
#  5   driver_race         86408 non-null  object
#  6   violation_raw       86408 non-null  object
#  7   violation           86408 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   search_type         3196 non-null   object
#  10  stop_outcome        86408 non-null  object
#  11  is_arrested         86408 non-null  object
#  12  stop_duration       86408 non-null  object
#  13  drugs_related_stop  91741 non-null  bool
#  14  s_date              91741 non-null  int32
# ...

# %%
data["stop_time"] = data["stop_time"].astype(str)
data["stop_time"] = pd.to_datetime(data["stop_time"], format="mixed")

# %%
data["s_min"] = pd.to_datetime(data["stop_time"]).dt.minute
data["s_hr"] = pd.to_datetime(data["stop_time"]).dt.hour

# %%
data
# Out:
#         stop_date           stop_time driver_gender  driver_age_raw  \
# 0      2005-01-02 2024-07-18 01:55:00             M          1985.0
# 1      2005-01-18 2024-07-18 08:15:00             M          1965.0
# 2      2005-01-23 2024-07-18 23:15:00             M          1972.0
# 3      2005-02-20 2024-07-18 17:15:00             M          1986.0
# 4      2005-03-14 2024-07-18 10:00:00             F          1984.0
# ...           ...                 ...           ...             ...
# 91736  2015-12-31 2024-07-18 20:27:00             M          1986.0
# 91737  2015-12-31 2024-07-18 20:35:00             F          1982.0
# 91738  2015-12-31 2024-07-18 20:45:00             M          1992.0
# 91739  2015-12-31 2024-07-18 21:42:00             M          1993.0
# 91740  2015-12-31 2024-07-18 22:46:00             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 0            20.0       White                        Speeding
# ...

# %%
data["stop_date"] = data["stop_date"].astype(str)
data["stop_date"] = pd.to_datetime(data["stop_date"], format="mixed")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  datetime64[ns]
#  1   stop_time           91741 non-null  datetime64[ns]
#  2   driver_gender       86406 non-null  object
#  3   driver_age_raw      86414 non-null  float64
#  4   driver_age          86120 non-null  float64
#  5   driver_race         86408 non-null  object
#  6   violation_raw       86408 non-null  object
#  7   violation           86408 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   search_type         3196 non-null   object
#  10  stop_outcome        86408 non-null  object
#  11  is_arrested         86408 non-null  object
#  12  stop_duration       86408 non-null  object
#  13  drugs_related_stop  91741 non-null  bool
#  14  s_date              91741 non-null  int32
# ...

# %%
data["s_mon"] = pd.to_datetime(data["stop_time"]).dt.month
data["s_day"] = pd.to_datetime(data["stop_time"]).dt.day

# %%
data
# Out:
#        stop_date           stop_time driver_gender  driver_age_raw  \
# 0     2005-01-02 2024-07-18 01:55:00             M          1985.0
# 1     2005-01-18 2024-07-18 08:15:00             M          1965.0
# 2     2005-01-23 2024-07-18 23:15:00             M          1972.0
# 3     2005-02-20 2024-07-18 17:15:00             M          1986.0
# 4     2005-03-14 2024-07-18 10:00:00             F          1984.0
# ...          ...                 ...           ...             ...
# 91736 2015-12-31 2024-07-18 20:27:00             M          1986.0
# 91737 2015-12-31 2024-07-18 20:35:00             F          1982.0
# 91738 2015-12-31 2024-07-18 20:45:00             M          1992.0
# 91739 2015-12-31 2024-07-18 21:42:00             M          1993.0
# 91740 2015-12-31 2024-07-18 22:46:00             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 0            20.0       White                        Speeding
# ...

# %%
data["stop_duration"].unique()
# Out:
# array(['0-15 Min', '16-30 Min', '30+ Min', nan, '2', '1'], dtype=object)

# %%
data[data["stop_duration"]=="30+ Min"]
# Out:
#        stop_date           stop_time driver_gender  driver_age_raw  \
# 22    2005-08-08 2024-07-18 02:09:00             M          1955.0
# 30    2005-09-26 2024-07-18 12:09:00             M          1959.0
# 41    2005-10-01 2024-07-18 00:00:00             M          1988.0
# 42    2005-10-01 2024-07-18 00:50:00             M          1977.0
# 80    2005-10-02 2024-07-18 09:30:00             M          1975.0
# ...          ...                 ...           ...             ...
# 91588 2015-12-22 2024-07-18 10:46:00             M          1945.0
# 91664 2015-12-28 2024-07-18 07:29:00             M          1954.0
# 91690 2015-12-29 2024-07-18 16:41:00             M          1991.0
# 91700 2015-12-30 2024-07-18 08:51:00             F          1987.0
# 91709 2015-12-30 2024-07-18 13:24:00             M          1967.0
#
#        driver_age driver_race                   violation_raw  \
# 22           50.0       Black         Other Traffic Violation
# ...

# %%
data.drop(["stop_date","stop_time"],axis=1,inplace=True)

# %%
data
# Out:
#       driver_gender  driver_age_raw  driver_age driver_race  \
# 0                 M          1985.0        20.0       White
# 1                 M          1965.0        40.0       White
# 2                 M          1972.0        33.0       White
# 3                 M          1986.0        19.0       White
# 4                 F          1984.0        21.0       White
# ...             ...             ...         ...         ...
# 91736             M          1986.0        29.0       White
# 91737             F          1982.0        33.0       White
# 91738             M          1992.0        23.0       White
# 91739             M          1993.0        22.0       White
# 91740             M          1959.0        56.0    Hispanic
#
#                         violation_raw         violation  search_conducted  \
# 0                            Speeding          Speeding             False
# 1                            Speeding          Speeding             False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   driver_gender       86406 non-null  object
#  1   driver_age_raw      86414 non-null  float64
#  2   driver_age          86120 non-null  float64
#  3   driver_race         86408 non-null  object
#  4   violation_raw       86408 non-null  object
#  5   violation           86408 non-null  object
#  6   search_conducted    91741 non-null  bool
#  7   search_type         3196 non-null   object
#  8   stop_outcome        86408 non-null  object
#  9   is_arrested         86408 non-null  object
#  10  stop_duration       86408 non-null  object
#  11  drugs_related_stop  91741 non-null  bool
#  12  s_date              91741 non-null  int32
#  13  s_time              91741 non-null  int32
#  14  s_min               91741 non-null  int32
# ...

# %%
data["driver_age"].unique()
# Out:
# array([20., 40., 33., 19., 21., 23., 36., 35., 26., 39., 50., 47., 52.,
#        38., nan, 41., 28., 46., 32., 58., 27., 43., 24., 17., 22., 44.,
#        48., 34., 55., 51., 45., 29., 31., 37., 67., 25., 42., 30., 18.,
#        57., 49., 61., 70., 53., 60., 59., 64., 63., 54., 56., 66., 62.,
#        69., 81., 68., 76., 75., 74., 82., 65., 72., 16., 77., 73., 71.,
#        80., 79., 78., 88., 15., 83., 86., 84., 85., 87., 99., 89., 94.,
#        90.])

# %%
data["driver_age"].head(50)
# Out:
# 0     20.0
# 1     40.0
# 2     33.0
# 3     19.0
# 4     21.0
# 5     23.0
# 6     36.0
# 7     19.0
# 8     35.0
# 9     35.0
# 10    26.0
# 11    39.0
# 12    26.0
# 13    21.0
# 14    36.0
# 15    23.0
# 16    23.0
# 17    26.0
# 18    50.0
# 19    47.0
# 20    26.0
# 21    52.0
# 22    50.0
# 23    38.0
# 24    26.0
# 25     NaN
# 26    41.0
# 27    28.0
# 28    21.0
# 29     NaN
# 30    46.0
# 31    23.0
# 32    32.0
# 33    52.0
# 34    58.0
# 35    27.0
# 36    19.0
# 37    43.0
# 38    24.0
# 39    17.0
# 40    17.0
# 41    17.0
# 42    28.0
# 43    20.0
# 44    22.0
# 45    44.0
# 46    46.0
# 47    33.0
# 48    48.0
# 49    34.0
# Name: driver_age, dtype: float64

# %%
data.iloc[25]
# Out:
# driver_gender           NaN
# driver_age_raw          NaN
# driver_age              NaN
# driver_race             NaN
# violation_raw           NaN
# violation               NaN
# search_conducted      False
# search_type             NaN
# stop_outcome            NaN
# is_arrested             NaN
# stop_duration           NaN
# drugs_related_stop    False
# s_date                    9
# s_time                    2
# s_min                     2
# s_hr                     16
# s_mon                     7
# s_day                    18
# Name: 25, dtype: object

# %%
data.iloc[23:45]
# Out:
#    driver_gender  driver_age_raw  driver_age driver_race  \
# 23             F          1967.0        38.0       White
# 24             M          1979.0        26.0       White
# 25           NaN             NaN         NaN         NaN
# 26             M          1964.0        41.0       White
# 27             F          1977.0        28.0       White
# 28             M          1984.0        21.0       White
# 29           NaN             NaN         NaN         NaN
# 30             M          1959.0        46.0       Black
# 31             M          1982.0        23.0       White
# 32             M          1973.0        32.0       White
# 33             M          1953.0        52.0       White
# 34             M          1947.0        58.0       White
# 35             M          1978.0        27.0       White
# 36             F          1986.0        19.0       White
# 37             M          1962.0        43.0       Asian
# ...

# %%
data.iloc[23:45:3]
# Out:
#    driver_gender  driver_age_raw  driver_age driver_race  \
# 23             F          1967.0        38.0       White
# 26             M          1964.0        41.0       White
# 29           NaN             NaN         NaN         NaN
# 32             M          1973.0        32.0       White
# 35             M          1978.0        27.0       White
# 38             M          1981.0        24.0       White
# 41             M          1988.0        17.0       White
# 44             M          1983.0        22.0       White
#
#                      violation_raw  violation  search_conducted  \
# 23                        Speeding   Speeding             False
# 26                        Speeding   Speeding             False
# 29                             NaN        NaN             False
# 32                        Speeding   Speeding             False
# 35  Equipment/Inspection Violation  Equipment             False
# ...

# %%
data[data["violation"]=="Speeding"]
# Out:
#       driver_gender  driver_age_raw  driver_age driver_race violation_raw  \
# 0                 M          1985.0        20.0       White      Speeding
# 1                 M          1965.0        40.0       White      Speeding
# 2                 M          1972.0        33.0       White      Speeding
# 4                 F          1984.0        21.0       White      Speeding
# 6                 M          1969.0        36.0       White      Speeding
# ...             ...             ...         ...         ...           ...
# 91734             M          1993.0        22.0       White      Speeding
# 91735             M          1992.0        23.0    Hispanic      Speeding
# 91736             M          1986.0        29.0       White      Speeding
# 91739             M          1993.0        22.0       White      Speeding
# 91740             M          1959.0        56.0    Hispanic      Speeding
#
#       violation  search_conducted search_type stop_outcome is_arrested  \
# ...

# %%
data[(data["violation"] == "Speeding") & (data["driver_race"] == "Hispanic")]
# Out:
#       driver_gender  driver_age_raw  driver_age driver_race violation_raw  \
# 320               M          1977.0        28.0    Hispanic      Speeding
# 413               M          1972.0        33.0    Hispanic      Speeding
# 535               M          1987.0        18.0    Hispanic      Speeding
# 576               M          1979.0        26.0    Hispanic      Speeding
# 594               M          1971.0        34.0    Hispanic      Speeding
# ...             ...             ...         ...         ...           ...
# 91714             M          1996.0        19.0    Hispanic      Speeding
# 91715             F          1994.0        21.0    Hispanic      Speeding
# 91728             F          1982.0        33.0    Hispanic      Speeding
# 91735             M          1992.0        23.0    Hispanic      Speeding
# 91740             M          1959.0        56.0    Hispanic      Speeding
#
#       violation  search_conducted search_type stop_outcome is_arrested  \
# ...

# %%
data[(data["violation"] == "Speeding") | (data["driver_age"] != 23.0)]
# Out:
#       driver_gender  driver_age_raw  driver_age driver_race  \
# 0                 M          1985.0        20.0       White
# 1                 M          1965.0        40.0       White
# 2                 M          1972.0        33.0       White
# 3                 M          1986.0        19.0       White
# 4                 F          1984.0        21.0       White
# ...             ...             ...         ...         ...
# 91735             M          1992.0        23.0    Hispanic
# 91736             M          1986.0        29.0       White
# 91737             F          1982.0        33.0       White
# 91739             M          1993.0        22.0       White
# 91740             M          1959.0        56.0    Hispanic
#
#                         violation_raw  violation  search_conducted  \
# 0                            Speeding   Speeding             False
# 1                            Speeding   Speeding             False
# ...

# %%
data[(data["violation"] == "Speeding") & (data["driver_age"] != 23.0)]
# Out:
#       driver_gender  driver_age_raw  driver_age driver_race violation_raw  \
# 0                 M          1985.0        20.0       White      Speeding
# 1                 M          1965.0        40.0       White      Speeding
# 2                 M          1972.0        33.0       White      Speeding
# 4                 F          1984.0        21.0       White      Speeding
# 6                 M          1969.0        36.0       White      Speeding
# ...             ...             ...         ...         ...           ...
# 91732             F          1969.0        46.0       White      Speeding
# 91734             M          1993.0        22.0       White      Speeding
# 91736             M          1986.0        29.0       White      Speeding
# 91739             M          1993.0        22.0       White      Speeding
# 91740             M          1959.0        56.0    Hispanic      Speeding
#
#       violation  search_conducted search_type stop_outcome is_arrested  \
# ...

# %%
data["violation"].str.len()
# Out:
# 0         8.0
# 1         8.0
# 2         8.0
# 3         5.0
# 4         8.0
#          ...
# 91736     8.0
# 91737     9.0
# 91738    16.0
# 91739     8.0
# 91740     8.0
# Name: violation, Length: 91741, dtype: float64

# %%
data.dtypes
# Out:
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# s_date                  int32
# s_time                  int32
# s_min                   int32
# s_hr                    int32
# s_mon                   int32
# s_day                   int32
# age                    object
# dtype: object

# %%
data.describe()
# Out:
#        driver_age_raw    driver_age        s_date        s_time         s_min  \
# count    86414.000000  86120.000000  91741.000000  91741.000000  91741.000000
# mean      1970.491228     34.011333      6.453167     28.818391     28.818391
# std        110.914909     12.738564      3.457557     17.339926     17.339926
# min          0.000000     15.000000      1.000000      0.000000      0.000000
# 25%       1967.000000     23.000000      3.000000     14.000000     14.000000
# 50%       1980.000000     31.000000      6.000000     30.000000     30.000000
# 75%       1987.000000     43.000000      9.000000     44.000000     44.000000
# max       8801.000000     99.000000     12.000000     59.000000     59.000000
#
#                s_hr    s_mon    s_day
# count  91741.000000  91741.0  91741.0
# mean      11.657885      7.0     18.0
# std        6.506469      0.0      0.0
# min        0.000000      7.0     18.0
# 25%        8.000000      7.0     18.0
# ...

# %%
data["violation"].str.upper()
# Out:
# 0                SPEEDING
# 1                SPEEDING
# 2                SPEEDING
# 3                   OTHER
# 4                SPEEDING
#                ...
# 91736            SPEEDING
# 91737           EQUIPMENT
# 91738    MOVING VIOLATION
# 91739            SPEEDING
# 91740            SPEEDING
# Name: violation, Length: 91741, dtype: object

# %%
data["violation"].str.lower()
# Out:
# 0                speeding
# 1                speeding
# 2                speeding
# 3                   other
# 4                speeding
#                ...
# 91736            speeding
# 91737           equipment
# 91738    moving violation
# 91739            speeding
# 91740            speeding
# Name: violation, Length: 91741, dtype: object

# %%
data["violation"].str.rstrip()
# Out:
# 0                Speeding
# 1                Speeding
# 2                Speeding
# 3                   Other
# 4                Speeding
#                ...
# 91736            Speeding
# 91737           Equipment
# 91738    Moving violation
# 91739            Speeding
# 91740            Speeding
# Name: violation, Length: 91741, dtype: object

# %%
data["violation"].str.lstrip()
# Out:
# 0                Speeding
# 1                Speeding
# 2                Speeding
# 3                   Other
# 4                Speeding
#                ...
# 91736            Speeding
# 91737           Equipment
# 91738    Moving violation
# 91739            Speeding
# 91740            Speeding
# Name: violation, Length: 91741, dtype: object
